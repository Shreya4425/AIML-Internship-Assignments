# %%
import numpy as np
import pandas as pd

# %%
products = pd.Series([70000, 1500, 3000], index = ["Laptop", "Mouse", "Keyboard"])
products    #prints full series
# Out:
# Laptop      70000
# Mouse        1500
# Keyboard     3000
# dtype: int64

# %%
products.loc["Laptop"]      #Label based access
# Out:
# np.int64(70000)

# %%
products.iloc[:2]           #Slicing first 2 products
# Out:
# Laptop    70000
# Mouse      1500
# dtype: int64

# %%
products
# Out:
# Laptop      70000
# Mouse        1500
# Keyboard     3000
# dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
grades = pd.Series([85, None, 92, 45, None, 78, 55])
grades
# Out:
# 0    85.0
# 1     NaN
# 2    92.0
# 3    45.0
# 4     NaN
# 5    78.0
# 6    55.0
# dtype: float64

# %%
grades.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
filled_grades = grades.fillna(0)
filled_grades
# Out:
# 0    85.0
# 1     0.0
# 2    92.0
# 3    45.0
# 4     0.0
# 5    78.0
# 6    55.0
# dtype: float64

# %%
filled_grades[filled_grades>60]
# Out:
# 0    85.0
# 2    92.0
# 5    78.0
# dtype: float64

# %%
grades
# Out:
# 0    85.0
# 1     NaN
# 2    92.0
# 3    45.0
# 4     NaN
# 5    78.0
# 6    55.0
# dtype: float64

# %%
import numpy as np
import pandas as pd

# %%
usernames = pd.Series([' Alice ', 'bOB', ' Charlie_Data ', 'daisy'])
usernames
# Out:
# 0            Alice
# 1               bOB
# 2     Charlie_Data
# 3             daisy
# dtype: object

# %%
cleaned = usernames.str.strip()
cleaned
# Out:
# 0           Alice
# 1             bOB
# 2    Charlie_Data
# 3           daisy
# dtype: object

# %%
new_names = cleaned.str.lower()
new_names
# Out:
# 0           alice
# 1             bob
# 2    charlie_data
# 3           daisy
# dtype: object

# %%
new_names.str.contains('a')
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool
